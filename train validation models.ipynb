# %%
#import the module
import EdgePrediction, json
import pandas as pd

# %%
from scipy.stats import hypergeom

# %%
def setup(files, optimisation, require_all):
    #create a new instance
    ep = EdgePrediction.EdgePrediction()
    
    ep.to_predict = 'risk_gene'
    ep.optimisation_method = optimisation
    ep.require_all_predictors = require_all
    
    for to_load in files:
        print(to_load)
        ep.CSV_to_graph(fname = to_load)
    
    nw_order = list(ep.graphs.keys()).sort()
    ep.network_order = nw_order
    ep.preprocess()
    
    return ep

# %%
def hyper_prob_at_least(pop_n, pop_true, draw_n, draw_true):
    #prob of at least h hits is i - cdf(h-1)
    prb = hypergeom.cdf(draw_true-1, pop_n, pop_true, draw_n)
    prb_h_plus = 1 - prb
    return prb_h_plus

# %%
def make_row(result, target_name, predictable, n_new_genes_total, verbose=True):
    row = {}
    a = set(result['new_hits'])
    n_validated = len(a.intersection(predictable))
    n_predicted = len(a)
    n_can_validate = len(predictable)
    if n_predicted > 0:
        validation_precision = n_validated / n_predicted
    else:
        validation_precision = 0.0
    validation_recall = n_validated / n_can_validate
    n_genes_total = sum(result['contingency'].values())
    n_genes_predicted_total = result['contingency']['tp'] + result['contingency']['fp']
    n_genes_train = result['contingency']['tp'] + result['contingency']['fn']
    
    keep = ['F1', 'F05', 'F2', 'ACC', 'J', 'PREC', 'REC', 'FDR', 'FPR', 'hits_total', 'hits_new', 'hits_known', 'model_built']
    row = {x:result[x] for x in keep}
    for x in ['tp', 'tn', 'fp', 'fn']:
        row[x] = result['contingency'][x]
    for name, weight in result['weights'].items():
        row['weight_' + name] = weight
    row['target'] = target_name
    
    row['validation_precision'] = validation_precision
    row['validation_recall'] = validation_recall
    row['n_genes_total'] = n_genes_total
    row['n_new_genes_total'] = n_new_genes_total
    row['n_new_genes_predictable'] = n_can_validate
    row['model_built'] = True
    row['n_validated'] = n_validated
    
    #hyper_prob_at_least(pop_n, pop_true, draw_n, draw_true)
    pop_n = result['contingency']['tn'] + result['contingency']['fp']
    pop_true = n_can_validate
    draw_n = n_predicted #this was tp+fp before but should only be fp i.e. new_hits
    draw_true = n_validated
    prob = hyper_prob_at_least(pop_n, pop_true, draw_n, draw_true)
    row['prob'] = prob
    
    if verbose:
        print("model for {} achieved {:.2f} validation rate at {:.2f} validation recall (found {}/{} with pred={})".format(target_name, validation_precision, validation_recall, n_validated, n_can_validate, n_predicted))
        print("predicted {}/{} genes associated with {} training genes".format(n_genes_predicted_total, n_genes_total, n_genes_train))
        print("predicted association rate {:.3f}".format(n_genes_predicted_total/n_genes_total))
        print("{}/{} new associations could have been predicted and were tested".format(n_can_validate, n_new_genes_total))
        print("p hyper {:0.3f}".format(prob))
        print()
    
    return row

# %%
def run(ep, to_train, valid):
    all_genes = set(ep.graphs['risk_gene']['sourcenodes'])
    rows = []
    n_todo = len(to_train)
    for tgt_idx in range(len(to_train)):
        print("{}/{}".format(tgt_idx, n_todo))
        target_name = to_train[tgt_idx]
        #check if any of the new associations can potentially be predicted
        new_genes = set(valid[target_name])
        predictable = new_genes.intersection(all_genes)
        if len(predictable) == 0:
            print("**** no predictable genes for", target_name)
            row = {'target': target_name, 'n_new_genes_predictable': 0, 'n_new_genes_total': len(new_genes)}
            rows.append(row)
            continue

        result = ep.predict(target = target_name, calculate_auc = True)
        if result['model_built'] == True:
            row = make_row(result, target_name, predictable, len(new_genes))
        else:
            row = {'target': target_name, 'n_new_genes_predictable': len(predictable), 'n_new_genes_total': len(new_genes)}
            row['model_built'] = False
        rows.append(row)
    return rows

# %%
files = [
         "train/disgenet_v7.0_train_2018.csv",
         "train/Gene Ontology v2020-11-17.csv",
         "train/IntAct v2020-11-06.csv"
         ]

# %%
with open('test/disgenet_new_since_2018.txt') as f:
    valid = json.load(f)

# %%
ep = setup(files, optimisation = 'graph_sparse', require_all=False)
# Out:
# train/disgenet_v7.0_train_2018.csv
# train/Gene Ontology v2020-11-17.csv
# train/IntAct v2020-11-06.csv
# 8107 source nodes are common to all 3 input graphs
# deleting 1002 nodes that don't overlap between networks
# deleting another 271 nodes that now have degree zero
# deleting 11604 nodes that don't overlap between networks
# deleting another 1942 nodes that now have degree zero
# deleting 13358 nodes that don't overlap between networks
# deleting another 2201 nodes that now have degree zero

# %%
possible_targets = set(ep.graphs['risk_gene']['targetnodes'])
print(len(possible_targets), 'diseases in network')
# Out:
# 10329 diseases in network

# %%
to_train_tmp = list(valid.keys())
to_train = [x for x in to_train_tmp if x in possible_targets]

# %% [markdown]
# Train all models. This can take ~ 2 hours.

# %%
rows = run(ep, to_train, valid)
# Out:
# 0/1131
# **** no predictable genes for C0036341
# 1/1131
# ignoring C0002395 as a predictor in network risk_gene
# model for C0002395 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=1095)
# predicted 1182.0/8107.0 genes associated with 88 training genes
# predicted association rate 0.146
# 1/1 new associations could have been predicted and were tested
# p hyper 0.137
#
# 2/1131
# ignoring C0007102 as a predictor in network risk_gene
# model for C0007102 achieved 0.00 validation rate at 0.33 validation recall (found 1/3 with pred=1160)
# predicted 1274.0/8107.0 genes associated with 147 training genes
# predicted association rate 0.157
# 3/5 new associations could have been predicted and were tested
# p hyper 0.377
#
# 3/1131
# ignoring C0009375 as a predictor in network risk_gene
# model for C0009375 achieved 0.00 validation rate at 0.50 validation recall (found 2/4 with pred=1009)
# predicted 1113.0/8107.0 genes associated with 140 training genes
# predicted association rate 0.137
# 4/5 new associations could have been predicted and were tested
# p hyper 0.081
#
# 4/1131
# ignoring C0011265 as a predictor in network risk_gene
# model for C0011265 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=1099)
# predicted 1183.0/8107.0 genes associated with 84 training genes
# predicted association rate 0.146
# 3/4 new associations could have been predicted and were tested
# p hyper 0.003
#
# 5/1131
# **** no predictable genes for C0022660
# 6/1131
# ignoring C0023893 as a predictor in network risk_gene
# model for C0023893 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=2203)
# predicted 2616.0/8107.0 genes associated with 732 training genes
# predicted association rate 0.323
# 1/1 new associations could have been predicted and were tested
# p hyper 0.299
#
# 7/1131
# ignoring C0024115 as a predictor in network risk_gene
# model for C0024115 achieved 0.00 validation rate at 0.23 validation recall (found 3/13 with pred=1390)
# predicted 1432.0/8107.0 genes associated with 54 training genes
# predicted association rate 0.177
# 13/19 new associations could have been predicted and were tested
# p hyper 0.395
#
# 8/1131
# ignoring C0024121 as a predictor in network risk_gene
# model for C0024121 achieved 0.00 validation rate at 0.20 validation recall (found 1/5 with pred=1040)
# predicted 1201.0/8107.0 genes associated with 228 training genes
# predicted association rate 0.148
# 5/5 new associations could have been predicted and were tested
# p hyper 0.507
#
# 9/1131
# ignoring C0027726 as a predictor in network risk_gene
# model for C0027726 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=529)
# predicted 550.0/8107.0 genes associated with 24 training genes
# predicted association rate 0.068
# 1/2 new associations could have been predicted and were tested
# p hyper 0.065
#
# 10/1131
# ignoring C0242379 as a predictor in network risk_gene
# model for C0242379 achieved 0.00 validation rate at 0.00 validation recall (found 0/3 with pred=1039)
# predicted 1201.0/8107.0 genes associated with 231 training genes
# predicted association rate 0.148
# 3/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 11/1131
# ignoring C0276496 as a predictor in network risk_gene
# model for C0276496 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=1095)
# predicted 1180.0/8107.0 genes associated with 85 training genes
# predicted association rate 0.146
# 3/4 new associations could have been predicted and were tested
# p hyper 0.003
#
# 12/1131
# ignoring C0494463 as a predictor in network risk_gene
# model for C0494463 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=1129)
# predicted 1214.0/8107.0 genes associated with 85 training genes
# predicted association rate 0.150
# 2/3 new associations could have been predicted and were tested
# p hyper 0.020
#
# 13/1131
# ignoring C0546126 as a predictor in network risk_gene
# model for C0546126 achieved 0.00 validation rate at 1.00 validation recall (found 4/4 with pred=1116)
# predicted 1199.0/8107.0 genes associated with 83 training genes
# predicted association rate 0.148
# 4/5 new associations could have been predicted and were tested
# p hyper 0.000
#
# 14/1131
# ignoring C0750900 as a predictor in network risk_gene
# model for C0750900 achieved 0.00 validation rate at 1.00 validation recall (found 4/4 with pred=1116)
# predicted 1199.0/8107.0 genes associated with 83 training genes
# predicted association rate 0.148
# 4/5 new associations could have been predicted and were tested
# p hyper 0.000
#
# 15/1131
# ignoring C0750901 as a predictor in network risk_gene
# model for C0750901 achieved 0.00 validation rate at 1.00 validation recall (found 4/4 with pred=1116)
# predicted 1199.0/8107.0 genes associated with 83 training genes
# predicted association rate 0.148
# 4/5 new associations could have been predicted and were tested
# p hyper 0.000
#
# 16/1131
# **** no predictable genes for C1565662
# 17/1131
# ignoring C2239176 as a predictor in network risk_gene
# model for C2239176 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1240)
# predicted 1499.0/8107.0 genes associated with 474 training genes
# predicted association rate 0.185
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 18/1131
# **** no predictable genes for C2609414
# 19/1131
# ignoring C0005684 as a predictor in network risk_gene
# model for C0005684 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=1171)
# predicted 1265.0/8107.0 genes associated with 127 training genes
# predicted association rate 0.156
# 3/3 new associations could have been predicted and were tested
# p hyper 0.003
#
# 20/1131
# ignoring C0005695 as a predictor in network risk_gene
# model for C0005695 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=1171)
# predicted 1265.0/8107.0 genes associated with 127 training genes
# predicted association rate 0.156
# 2/2 new associations could have been predicted and were tested
# p hyper 0.022
#
# 21/1131
# **** no predictable genes for C0006826
# 22/1131
# ignoring C0013221 as a predictor in network risk_gene
# model for C0013221 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=868)
# predicted 938.0/8107.0 genes associated with 82 training genes
# predicted association rate 0.116
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 23/1131
# ignoring C0028796 as a predictor in network risk_gene
# model for C0028796 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=0)
# predicted 6.0/8107.0 genes associated with 6 training genes
# predicted association rate 0.001
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 24/1131
# ignoring C0033578 as a predictor in network risk_gene
# model for C0033578 achieved 0.00 validation rate at 1.00 validation recall (found 6/6 with pred=4215)
# predicted 4798.0/8107.0 genes associated with 583 training genes
# predicted association rate 0.592
# 6/6 new associations could have been predicted and were tested
# p hyper 0.031
#
# 25/1131
# ignoring C0041755 as a predictor in network risk_gene
# model for C0041755 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=868)
# predicted 938.0/8107.0 genes associated with 82 training genes
# predicted association rate 0.116
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 26/1131
# ignoring C0086457 as a predictor in network risk_gene
# model for C0086457 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=0)
# predicted 6.0/8107.0 genes associated with 6 training genes
# predicted association rate 0.001
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 27/1131
# ignoring C0086692 as a predictor in network risk_gene
# model for C0086692 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=2546)
# predicted 2609.0/8107.0 genes associated with 63 training genes
# predicted association rate 0.322
# 1/1 new associations could have been predicted and were tested
# p hyper 0.317
#
# 28/1131
# ignoring C0376358 as a predictor in network risk_gene
# model for C0376358 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=3924)
# predicted 4509.0/8107.0 genes associated with 586 training genes
# predicted association rate 0.556
# 3/3 new associations could have been predicted and were tested
# p hyper 0.142
#
# 29/1131
# ignoring C0006142 as a predictor in network risk_gene
# model for C0006142 achieved 0.01 validation rate at 0.13 validation recall (found 19/144 with pred=1522)
# predicted 2048.0/8107.0 genes associated with 667 training genes
# predicted association rate 0.253
# 144/344 new associations could have been predicted and were tested
# p hyper 0.992
#
# 30/1131
# ignoring C0011999 as a predictor in network risk_gene
# model for C0011999 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 31/1131
# ignoring C0019193 as a predictor in network risk_gene
# model for C0019193 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 32/1131
# ignoring C0023452 as a predictor in network risk_gene
# model for C0023452 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=425)
# predicted 467.0/8107.0 genes associated with 49 training genes
# predicted association rate 0.058
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 33/1131
# ignoring C0023453 as a predictor in network risk_gene
# model for C0023453 achieved 0.00 validation rate at 0.17 validation recall (found 1/6 with pred=409)
# predicted 445.0/8107.0 genes associated with 42 training genes
# predicted association rate 0.055
# 6/7 new associations could have been predicted and were tested
# p hyper 0.268
#
# 34/1131
# ignoring C0023903 as a predictor in network risk_gene
# model for C0023903 achieved 0.00 validation rate at 0.67 validation recall (found 2/3 with pred=3559)
# predicted 3685.0/8107.0 genes associated with 126 training genes
# predicted association rate 0.455
# 3/4 new associations could have been predicted and were tested
# p hyper 0.419
#
# 35/1131
# ignoring C0027806 as a predictor in network risk_gene
# model for C0027806 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 36/1131
# ignoring C0080218 as a predictor in network risk_gene
# model for C0080218 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 37/1131
# ignoring C0152234 as a predictor in network risk_gene
# model for C0152234 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 38/1131
# ignoring C0152426 as a predictor in network risk_gene
# model for C0152426 achieved 0.02 validation rate at 1.00 validation recall (found 3/3 with pred=141)
# predicted 165.0/8107.0 genes associated with 24 training genes
# predicted association rate 0.020
# 3/3 new associations could have been predicted and were tested
# p hyper 0.000
#
# 39/1131
# ignoring C0266453 as a predictor in network risk_gene
# model for C0266453 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 40/1131
# ignoring C0344479 as a predictor in network risk_gene
# model for C0344479 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 41/1131
# ignoring C0345904 as a predictor in network risk_gene
# model for C0345904 achieved 0.00 validation rate at 0.67 validation recall (found 2/3 with pred=3559)
# predicted 3685.0/8107.0 genes associated with 126 training genes
# predicted association rate 0.455
# 3/4 new associations could have been predicted and were tested
# p hyper 0.419
#
# 42/1131
# ignoring C0678222 as a predictor in network risk_gene
# model for C0678222 achieved 0.00 validation rate at 0.00 validation recall (found 0/3 with pred=1831)
# predicted 2307.0/8107.0 genes associated with 480 training genes
# predicted association rate 0.285
# 3/5 new associations could have been predicted and were tested
# p hyper 1.000
#
# 43/1131
# ignoring C0702169 as a predictor in network risk_gene
# model for C0702169 achieved 0.03 validation rate at 0.33 validation recall (found 1/3 with pred=29)
# predicted 52.0/8107.0 genes associated with 23 training genes
# predicted association rate 0.006
# 3/3 new associations could have been predicted and were tested
# p hyper 0.011
#
# 44/1131
# ignoring C0860207 as a predictor in network risk_gene
# model for C0860207 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 45/1131
# ignoring C1257931 as a predictor in network risk_gene
# model for C1257931 achieved 0.01 validation rate at 0.88 validation recall (found 14/16 with pred=1821)
# predicted 2276.0/8107.0 genes associated with 455 training genes
# predicted association rate 0.281
# 16/17 new associations could have been predicted and were tested
# p hyper 0.000
#
# 46/1131
# ignoring C1262760 as a predictor in network risk_gene
# model for C1262760 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 47/1131
# ignoring C1458155 as a predictor in network risk_gene
# model for C1458155 achieved 0.00 validation rate at 0.50 validation recall (found 2/4 with pred=1840)
# predicted 2307.0/8107.0 genes associated with 469 training genes
# predicted association rate 0.285
# 4/5 new associations could have been predicted and were tested
# p hyper 0.246
#
# 48/1131
# ignoring C1961102 as a predictor in network risk_gene
# model for C1961102 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1628)
# predicted 1686.0/8107.0 genes associated with 58 training genes
# predicted association rate 0.208
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 49/1131
# ignoring C3658290 as a predictor in network risk_gene
# model for C3658290 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 50/1131
# ignoring C4277682 as a predictor in network risk_gene
# model for C4277682 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 51/1131
# ignoring C4279912 as a predictor in network risk_gene
# model for C4279912 achieved 0.00 validation rate at 0.75 validation recall (found 3/4 with pred=1563)
# predicted 1833.0/8107.0 genes associated with 270 training genes
# predicted association rate 0.226
# 4/4 new associations could have been predicted and were tested
# p hyper 0.027
#
# 52/1131
# ignoring C4704874 as a predictor in network risk_gene
# model for C4704874 achieved 0.01 validation rate at 0.88 validation recall (found 14/16 with pred=1821)
# predicted 2276.0/8107.0 genes associated with 455 training genes
# predicted association rate 0.281
# 16/17 new associations could have been predicted and were tested
# p hyper 0.000
#
# 53/1131
# ignoring C0005587 as a predictor in network risk_gene
# model for C0005587 achieved 0.01 validation rate at 0.22 validation recall (found 4/18 with pred=687)
# predicted 737.0/8107.0 genes associated with 51 training genes
# predicted association rate 0.091
# 18/27 new associations could have been predicted and were tested
# p hyper 0.061
#
# 54/1131
# ignoring C0393770 as a predictor in network risk_gene
# model for C0393770 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 55/1131
# ignoring C0494410 as a predictor in network risk_gene
# model for C0494410 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 56/1131
# ignoring C0751758 as a predictor in network risk_gene
# model for C0751758 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 57/1131
# ignoring C0751759 as a predictor in network risk_gene
# model for C0751759 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 58/1131
# ignoring C0751760 as a predictor in network risk_gene
# model for C0751760 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 59/1131
# ignoring C0877792 as a predictor in network risk_gene
# model for C0877792 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 4.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 60/1131
# ignoring C0004352 as a predictor in network risk_gene
# model for C0004352 achieved 0.00 validation rate at 0.40 validation recall (found 2/5 with pred=1324)
# predicted 1486.0/8107.0 genes associated with 243 training genes
# predicted association rate 0.183
# 5/6 new associations could have been predicted and were tested
# p hyper 0.199
#
# 61/1131
# ignoring C0026827 as a predictor in network risk_gene
# model for C0026827 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=654)
# predicted 667.0/8107.0 genes associated with 14 training genes
# predicted association rate 0.082
# 2/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 62/1131
# ignoring C0036572 as a predictor in network risk_gene
# model for C0036572 achieved 0.00 validation rate at 0.13 validation recall (found 2/15 with pred=1266)
# predicted 1413.0/8107.0 genes associated with 186 training genes
# predicted association rate 0.174
# 15/30 new associations could have been predicted and were tested
# p hyper 0.718
#
# 63/1131
# ignoring C0270844 as a predictor in network risk_gene
# model for C0270844 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=93)
# predicted 193.0/8107.0 genes associated with 100 training genes
# predicted association rate 0.024
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 64/1131
# ignoring C0424605 as a predictor in network risk_gene
# model for C0424605 achieved 0.00 validation rate at 0.00 validation recall (found 0/6 with pred=510)
# predicted 541.0/8107.0 genes associated with 31 training genes
# predicted association rate 0.067
# 6/6 new associations could have been predicted and were tested
# p hyper 1.000
#
# 65/1131
# ignoring C0494475 as a predictor in network risk_gene
# model for C0494475 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=93)
# predicted 193.0/8107.0 genes associated with 101 training genes
# predicted association rate 0.024
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 66/1131
# ignoring C0557874 as a predictor in network risk_gene
# model for C0557874 achieved 0.01 validation rate at 0.25 validation recall (found 6/24 with pred=496)
# predicted 576.0/8107.0 genes associated with 86 training genes
# predicted association rate 0.071
# 24/46 new associations could have been predicted and were tested
# p hyper 0.003
#
# 67/1131
# ignoring C0751495 as a predictor in network risk_gene
# model for C0751495 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=92)
# predicted 192.0/8107.0 genes associated with 102 training genes
# predicted association rate 0.024
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 68/1131
# ignoring C4048158 as a predictor in network risk_gene
# model for C4048158 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=93)
# predicted 193.0/8107.0 genes associated with 100 training genes
# predicted association rate 0.024
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 69/1131
# ignoring C4316903 as a predictor in network risk_gene
# model for C4316903 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=93)
# predicted 193.0/8107.0 genes associated with 100 training genes
# predicted association rate 0.024
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 70/1131
# ignoring C4317123 as a predictor in network risk_gene
# model for C4317123 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=93)
# predicted 193.0/8107.0 genes associated with 100 training genes
# predicted association rate 0.024
# 2/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 71/1131
# ignoring C0004153 as a predictor in network risk_gene
# model for C0004153 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=653)
# predicted 706.0/8107.0 genes associated with 56 training genes
# predicted association rate 0.087
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 72/1131
# ignoring C0009402 as a predictor in network risk_gene
# model for C0009402 achieved 0.01 validation rate at 0.11 validation recall (found 15/136 with pred=1617)
# predicted 1876.0/8107.0 genes associated with 380 training genes
# predicted association rate 0.231
# 136/296 new associations could have been predicted and were tested
# p hyper 0.999
#
# 73/1131
# ignoring C0009404 as a predictor in network risk_gene
# model for C0009404 achieved 0.00 validation rate at 0.43 validation recall (found 6/14 with pred=1312)
# predicted 1493.0/8107.0 genes associated with 242 training genes
# predicted association rate 0.184
# 14/17 new associations could have been predicted and were tested
# p hyper 0.019
#
# 74/1131
# ignoring C0020443 as a predictor in network risk_gene
# model for C0020443 achieved 0.01 validation rate at 0.83 validation recall (found 5/6 with pred=429)
# predicted 458.0/8107.0 genes associated with 32 training genes
# predicted association rate 0.056
# 6/6 new associations could have been predicted and were tested
# p hyper 0.000
#
# 75/1131
# **** no predictable genes for C0745103
# 76/1131
# ignoring C1563937 as a predictor in network risk_gene
# model for C1563937 achieved 0.00 validation rate at 0.50 validation recall (found 1/2 with pred=641)
# predicted 693.0/8107.0 genes associated with 55 training genes
# predicted association rate 0.085
# 2/3 new associations could have been predicted and were tested
# p hyper 0.153
#
# 77/1131
# ignoring C4721453 as a predictor in network risk_gene
# model for C4721453 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=1033)
# predicted 1068.0/8107.0 genes associated with 51 training genes
# predicted association rate 0.132
# 1/1 new associations could have been predicted and were tested
# p hyper 0.128
#
# 78/1131
# ignoring C0020542 as a predictor in network risk_gene
# model for C0020542 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=1190)
# predicted 1223.0/8107.0 genes associated with 35 training genes
# predicted association rate 0.151
# 2/2 new associations could have been predicted and were tested
# p hyper 0.022
#
# 79/1131
# ignoring C0034069 as a predictor in network risk_gene
# model for C0034069 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=542)
# predicted 604.0/8107.0 genes associated with 71 training genes
# predicted association rate 0.075
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 80/1131
# ignoring C4721507 as a predictor in network risk_gene
# model for C4721507 achieved 0.01 validation rate at 0.67 validation recall (found 2/3 with pred=374)
# predicted 433.0/8107.0 genes associated with 67 training genes
# predicted association rate 0.053
# 3/4 new associations could have been predicted and were tested
# p hyper 0.006
#
# 81/1131
# **** no predictable genes for C0004134
# 82/1131
# ignoring C0032300 as a predictor in network risk_gene
# model for C0032300 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=362)
# predicted 413.0/8107.0 genes associated with 52 training genes
# predicted association rate 0.051
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 83/1131
# ignoring C0235874 as a predictor in network risk_gene
# model for C0235874 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=1382)
# predicted 1513.0/8107.0 genes associated with 151 training genes
# predicted association rate 0.187
# 2/2 new associations could have been predicted and were tested
# p hyper 0.030
#
# 84/1131
# ignoring C0887898 as a predictor in network risk_gene
# model for C0887898 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=362)
# predicted 413.0/8107.0 genes associated with 52 training genes
# predicted association rate 0.051
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 85/1131
# ignoring C0008924 as a predictor in network risk_gene
# model for C0008924 achieved 0.00 validation rate at 0.33 validation recall (found 1/3 with pred=784)
# predicted 817.0/8107.0 genes associated with 35 training genes
# predicted association rate 0.101
# 3/3 new associations could have been predicted and were tested
# p hyper 0.264
#
# 86/1131
# ignoring C0015397 as a predictor in network risk_gene
# model for C0015397 achieved 0.31 validation rate at 0.78 validation recall (found 114/146 with pred=373)
# predicted 418.0/8107.0 genes associated with 49 training genes
# predicted association rate 0.052
# 146/160 new associations could have been predicted and were tested
# p hyper 0.000
#
# 87/1131
# ignoring C0035334 as a predictor in network risk_gene
# model for C0035334 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=321)
# predicted 389.0/8107.0 genes associated with 94 training genes
# predicted association rate 0.048
# 1/2 new associations could have been predicted and were tested
# p hyper 0.040
#
# 88/1131
# ignoring C0242383 as a predictor in network risk_gene
# model for C0242383 achieved 0.00 validation rate at 0.25 validation recall (found 1/4 with pred=715)
# predicted 735.0/8107.0 genes associated with 26 training genes
# predicted association rate 0.091
# 4/4 new associations could have been predicted and were tested
# p hyper 0.310
#
# 89/1131
# ignoring C0006413 as a predictor in network risk_gene
# model for C0006413 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=554)
# predicted 587.0/8107.0 genes associated with 33 training genes
# predicted association rate 0.072
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 90/1131
# ignoring C0014859 as a predictor in network risk_gene
# model for C0014859 achieved 0.00 validation rate at 0.25 validation recall (found 1/4 with pred=1012)
# predicted 1071.0/8107.0 genes associated with 67 training genes
# predicted association rate 0.132
# 4/5 new associations could have been predicted and were tested
# p hyper 0.416
#
# 91/1131
# **** no predictable genes for C0015544
# 92/1131
# ignoring C0018798 as a predictor in network risk_gene
# model for C0018798 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=775)
# predicted 808.0/8107.0 genes associated with 41 training genes
# predicted association rate 0.100
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 93/1131
# ignoring C0023473 as a predictor in network risk_gene
# model for C0023473 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=728)
# predicted 752.0/8107.0 genes associated with 28 training genes
# predicted association rate 0.093
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 94/1131
# ignoring C0025202 as a predictor in network risk_gene
# model for C0025202 achieved 0.00 validation rate at 0.00 validation recall (found 0/3 with pred=1171)
# predicted 1299.0/8107.0 genes associated with 228 training genes
# predicted association rate 0.160
# 3/4 new associations could have been predicted and were tested
# p hyper 1.000
#
# 95/1131
# **** no predictable genes for C0039075
# 96/1131
# ignoring C0546837 as a predictor in network risk_gene
# model for C0546837 achieved 0.00 validation rate at 0.33 validation recall (found 2/6 with pred=1107)
# predicted 1164.0/8107.0 genes associated with 64 training genes
# predicted association rate 0.144
# 6/8 new associations could have been predicted and were tested
# p hyper 0.195
#
# 97/1131
# **** no predictable genes for C1961099
# 98/1131
# ignoring C0018800 as a predictor in network risk_gene
# model for C0018800 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1150)
# predicted 1219.0/8107.0 genes associated with 78 training genes
# predicted association rate 0.150
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 99/1131
# ignoring C1383860 as a predictor in network risk_gene
# model for C1383860 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1150)
# predicted 1219.0/8107.0 genes associated with 78 training genes
# predicted association rate 0.150
# 1/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 100/1131
# ignoring C0030297 as a predictor in network risk_gene
# model for C0030297 achieved 0.00 validation rate at 0.50 validation recall (found 1/2 with pred=708)
# predicted 781.0/8107.0 genes associated with 93 training genes
# predicted association rate 0.096
# 2/3 new associations could have been predicted and were tested
# p hyper 0.169
#
# 101/1131
# ignoring C0346647 as a predictor in network risk_gene
# model for C0346647 achieved 0.00 validation rate at 0.50 validation recall (found 1/2 with pred=772)
# predicted 848.0/8107.0 genes associated with 95 training genes
# predicted association rate 0.105
# 2/3 new associations could have been predicted and were tested
# p hyper 0.183
#
# 102/1131
# ignoring C0525045 as a predictor in network risk_gene
# model for C0525045 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1112)
# predicted 1251.0/8107.0 genes associated with 156 training genes
# predicted association rate 0.154
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 103/1131
# ignoring C4721610 as a predictor in network risk_gene
# model for C4721610 achieved 0.00 validation rate at 0.00 validation recall (found 0/3 with pred=222)
# predicted 230.0/8107.0 genes associated with 21 training genes
# predicted association rate 0.028
# 3/4 new associations could have been predicted and were tested
# p hyper 1.000
#
# 104/1131
# ignoring C0023212 as a predictor in network risk_gene
# model for C0023212 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1016)
# predicted 1119.0/8107.0 genes associated with 108 training genes
# predicted association rate 0.138
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 105/1131
# ignoring C0235527 as a predictor in network risk_gene
# model for C0235527 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1016)
# predicted 1119.0/8107.0 genes associated with 108 training genes
# predicted association rate 0.138
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 106/1131
# ignoring C1959583 as a predictor in network risk_gene
# model for C1959583 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1016)
# predicted 1119.0/8107.0 genes associated with 108 training genes
# predicted association rate 0.138
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 107/1131
# ignoring C1961112 as a predictor in network risk_gene
# model for C1961112 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1016)
# predicted 1119.0/8107.0 genes associated with 108 training genes
# predicted association rate 0.138
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 108/1131
# ignoring C0028754 as a predictor in network risk_gene
# model for C0028754 achieved 0.00 validation rate at 0.14 validation recall (found 1/7 with pred=1114)
# predicted 1247.0/8107.0 genes associated with 187 training genes
# predicted association rate 0.154
# 7/7 new associations could have been predicted and were tested
# p hyper 0.654
#
# 109/1131
# ignoring C0043094 as a predictor in network risk_gene
# model for C0043094 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=1879)
# predicted 1939.0/8107.0 genes associated with 97 training genes
# predicted association rate 0.239
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 110/1131
# ignoring C0005586 as a predictor in network risk_gene
# model for C0005586 achieved 0.00 validation rate at 0.50 validation recall (found 5/10 with pred=2369)
# predicted 2725.0/8107.0 genes associated with 422 training genes
# predicted association rate 0.336
# 10/18 new associations could have been predicted and were tested
# p hyper 0.165
#
# 111/1131
# ignoring C0369183 as a predictor in network risk_gene
# model for C0369183 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=0)
# predicted 11.0/8107.0 genes associated with 11 training genes
# predicted association rate 0.001
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 112/1131
# ignoring C1261502 as a predictor in network risk_gene
# model for C1261502 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=0)
# predicted 11.0/8107.0 genes associated with 11 training genes
# predicted association rate 0.001
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 113/1131
# ignoring C0025261 as a predictor in network risk_gene
# model for C0025261 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=412)
# predicted 451.0/8107.0 genes associated with 39 training genes
# predicted association rate 0.056
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 114/1131
# ignoring C0026650 as a predictor in network risk_gene
# model for C0026650 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=664)
# predicted 690.0/8107.0 genes associated with 27 training genes
# predicted association rate 0.085
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 115/1131
# **** no predictable genes for C0040822
# 116/1131
# ignoring C0233794 as a predictor in network risk_gene
# model for C0233794 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=419)
# predicted 459.0/8107.0 genes associated with 40 training genes
# predicted association rate 0.057
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 117/1131
# ignoring C0279702 as a predictor in network risk_gene
# model for C0279702 achieved 0.00 validation rate at 0.25 validation recall (found 2/8 with pred=994)
# predicted 1118.0/8107.0 genes associated with 131 training genes
# predicted association rate 0.138
# 8/10 new associations could have been predicted and were tested
# p hyper 0.262
#
# 118/1131
# ignoring C0751292 as a predictor in network risk_gene
# model for C0751292 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=412)
# predicted 451.0/8107.0 genes associated with 39 training genes
# predicted association rate 0.056
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 119/1131
# ignoring C0751293 as a predictor in network risk_gene
# model for C0751293 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=412)
# predicted 451.0/8107.0 genes associated with 39 training genes
# predicted association rate 0.056
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 120/1131
# ignoring C0751294 as a predictor in network risk_gene
# model for C0751294 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=412)
# predicted 451.0/8107.0 genes associated with 39 training genes
# predicted association rate 0.056
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 121/1131
# ignoring C0751295 as a predictor in network risk_gene
# model for C0751295 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=412)
# predicted 451.0/8107.0 genes associated with 39 training genes
# predicted association rate 0.056
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 122/1131
# ignoring C1266042 as a predictor in network risk_gene
# model for C1266042 achieved 0.00 validation rate at 0.25 validation recall (found 1/4 with pred=980)
# predicted 1096.0/8107.0 genes associated with 118 training genes
# predicted association rate 0.135
# 4/4 new associations could have been predicted and were tested
# p hyper 0.408
#
# 123/1131
# ignoring C1266043 as a predictor in network risk_gene
# model for C1266043 achieved 0.00 validation rate at 0.57 validation recall (found 4/7 with pred=1036)
# predicted 1151.0/8107.0 genes associated with 115 training genes
# predicted association rate 0.142
# 7/7 new associations could have been predicted and were tested
# p hyper 0.007
#
# 124/1131
# ignoring C1266044 as a predictor in network risk_gene
# model for C1266044 achieved 0.00 validation rate at 0.50 validation recall (found 3/6 with pred=999)
# predicted 1114.0/8107.0 genes associated with 116 training genes
# predicted association rate 0.137
# 6/6 new associations could have been predicted and were tested
# p hyper 0.029
#
# 125/1131
# ignoring C1306837 as a predictor in network risk_gene
# model for C1306837 achieved 0.00 validation rate at 0.60 validation recall (found 3/5 with pred=999)
# predicted 1114.0/8107.0 genes associated with 117 training genes
# predicted association rate 0.137
# 5/5 new associations could have been predicted and were tested
# p hyper 0.016
#
# 126/1131
# ignoring C0027626 as a predictor in network risk_gene
# model for C0027626 achieved 0.00 validation rate at 0.50 validation recall (found 1/2 with pred=1499)
# predicted 1637.0/8107.0 genes associated with 162 training genes
# predicted association rate 0.202
# 2/4 new associations could have been predicted and were tested
# p hyper 0.342
#
# 127/1131
# ignoring C0029408 as a predictor in network risk_gene
# model for C0029408 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=328)
# predicted 413.0/8107.0 genes associated with 90 training genes
# predicted association rate 0.051
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 128/1131
# ignoring C0086743 as a predictor in network risk_gene
# model for C0086743 achieved 0.02 validation rate at 0.86 validation recall (found 6/7 with pred=334)
# predicted 418.0/8107.0 genes associated with 84 training genes
# predicted association rate 0.052
# 7/8 new associations could have been predicted and were tested
# p hyper 0.000
#
# 129/1131
# ignoring C3860213 as a predictor in network risk_gene
# model for C3860213 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=840)
# predicted 866.0/8107.0 genes associated with 32 training genes
# predicted association rate 0.107
# 2/2 new associations could have been predicted and were tested
# p hyper 0.011
#
# 130/1131
# ignoring C0087031 as a predictor in network risk_gene
# model for C0087031 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=52)
# predicted 175.0/8107.0 genes associated with 125 training genes
# predicted association rate 0.022
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 131/1131
# ignoring C0007193 as a predictor in network risk_gene
# model for C0007193 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=884)
# predicted 929.0/8107.0 genes associated with 47 training genes
# predicted association rate 0.115
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 132/1131
# ignoring C0007194 as a predictor in network risk_gene
# model for C0007194 achieved 0.01 validation rate at 0.75 validation recall (found 3/4 with pred=343)
# predicted 392.0/8107.0 genes associated with 53 training genes
# predicted association rate 0.048
# 4/4 new associations could have been predicted and were tested
# p hyper 0.000
#
# 133/1131
# ignoring C0546264 as a predictor in network risk_gene
# model for C0546264 achieved 0.04 validation rate at 1.00 validation recall (found 4/4 with pred=106)
# predicted 118.0/8107.0 genes associated with 14 training genes
# predicted association rate 0.015
# 4/4 new associations could have been predicted and were tested
# p hyper 0.000
#
# 134/1131
# ignoring C0014175 as a predictor in network risk_gene
# model for C0014175 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=273)
# predicted 424.0/8107.0 genes associated with 154 training genes
# predicted association rate 0.052
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 135/1131
# ignoring C0026654 as a predictor in network risk_gene
# model for C0026654 achieved 0.00 validation rate at 0.00 validation recall (found 0/4 with pred=15)
# predicted 20.0/8107.0 genes associated with 11 training genes
# predicted association rate 0.002
# 4/5 new associations could have been predicted and were tested
# p hyper 1.000
#
# 136/1131
# ignoring C0036421 as a predictor in network risk_gene
# model for C0036421 achieved 0.00 validation rate at 0.00 validation recall (found 0/2 with pred=6)
# predicted 9.0/8107.0 genes associated with 16 training genes
# predicted association rate 0.001
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 137/1131
# ignoring C0086432 as a predictor in network risk_gene
# model for C0086432 achieved 0.01 validation rate at 1.00 validation recall (found 6/6 with pred=1163)
# predicted 1184.0/8107.0 genes associated with 21 training genes
# predicted association rate 0.146
# 6/7 new associations could have been predicted and were tested
# p hyper 0.000
#
# 138/1131
# ignoring C0086565 as a predictor in network risk_gene
# model for C0086565 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=3338)
# predicted 3407.0/8107.0 genes associated with 69 training genes
# predicted association rate 0.420
# 1/1 new associations could have been predicted and were tested
# p hyper 0.415
#
# 139/1131
# ignoring C0162872 as a predictor in network risk_gene
# model for C0162872 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=3)
# predicted 9.0/8107.0 genes associated with 6 training genes
# predicted association rate 0.001
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 140/1131
# ignoring C0269102 as a predictor in network risk_gene
# model for C0269102 achieved 0.01 validation rate at 0.60 validation recall (found 3/5 with pred=315)
# predicted 466.0/8107.0 genes associated with 151 training genes
# predicted association rate 0.057
# 5/5 new associations could have been predicted and were tested
# p hyper 0.001
#
# 141/1131
# ignoring C0340630 as a predictor in network risk_gene
# model for C0340630 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=3)
# predicted 9.0/8107.0 genes associated with 6 training genes
# predicted association rate 0.001
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 142/1131
# ignoring C4707243 as a predictor in network risk_gene
# model for C4707243 achieved 0.05 validation rate at 0.37 validation recall (found 10/27 with pred=216)
# predicted 234.0/8107.0 genes associated with 21 training genes
# predicted association rate 0.029
# 27/29 new associations could have been predicted and were tested
# p hyper 0.000
#
# 143/1131
# ignoring C0009363 as a predictor in network risk_gene
# model for C0009363 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=11)
# predicted 17.0/8107.0 genes associated with 6 training genes
# predicted association rate 0.002
# 1/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 144/1131
# ignoring C0013421 as a predictor in network risk_gene
# model for C0013421 achieved 0.01 validation rate at 0.77 validation recall (found 10/13 with pred=1014)
# predicted 1067.0/8107.0 genes associated with 70 training genes
# predicted association rate 0.132
# 13/15 new associations could have been predicted and were tested
# p hyper 0.000
#
# 145/1131
# **** no predictable genes for C0018784
# 146/1131
# ignoring C0376634 as a predictor in network risk_gene
# model for C0376634 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=972)
# predicted 1093.0/8107.0 genes associated with 144 training genes
# predicted association rate 0.135
# 1/1 new associations could have been predicted and were tested
# p hyper 0.122
#
# 147/1131
# ignoring C0393588 as a predictor in network risk_gene
# model for C0393588 achieved 0.03 validation rate at 1.00 validation recall (found 3/3 with pred=87)
# predicted 101.0/8107.0 genes associated with 14 training genes
# predicted association rate 0.012
# 3/3 new associations could have been predicted and were tested
# p hyper 0.000
#
# 148/1131
# ignoring C0393610 as a predictor in network risk_gene
# model for C0393610 achieved 0.04 validation rate at 0.33 validation recall (found 1/3 with pred=27)
# predicted 40.0/8107.0 genes associated with 13 training genes
# predicted association rate 0.005
# 3/3 new associations could have been predicted and were tested
# p hyper 0.010
#
# 149/1131
# ignoring C0751093 as a predictor in network risk_gene
# model for C0751093 achieved 0.04 validation rate at 0.33 validation recall (found 1/3 with pred=27)
# predicted 40.0/8107.0 genes associated with 13 training genes
# predicted association rate 0.005
# 3/3 new associations could have been predicted and were tested
# p hyper 0.010
#
# 150/1131
# ignoring C4554007 as a predictor in network risk_gene
# model for C4554007 achieved 0.22 validation rate at 1.00 validation recall (found 2/2 with pred=9)
# predicted 13.0/8107.0 genes associated with 4 training genes
# predicted association rate 0.002
# 2/3 new associations could have been predicted and were tested
# p hyper 0.000
#
# 151/1131
# ignoring C0024623 as a predictor in network risk_gene
# model for C0024623 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=2099)
# predicted 2358.0/8107.0 genes associated with 290 training genes
# predicted association rate 0.291
# 1/2 new associations could have been predicted and were tested
# p hyper 0.269
#
# 152/1131
# ignoring C0038356 as a predictor in network risk_gene
# ...
# model for C1865872 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=44)
# predicted 50.0/8107.0 genes associated with 7 training genes
# predicted association rate 0.006
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1078/1131
# ignoring C0265215 as a predictor in network risk_gene
# model for C0265215 achieved 0.05 validation rate at 1.00 validation recall (found 2/2 with pred=42)
# predicted 54.0/8107.0 genes associated with 12 training genes
# predicted association rate 0.007
# 2/2 new associations could have been predicted and were tested
# p hyper 0.000
#
# 1079/1131
# ignoring C3714506 as a predictor in network risk_gene
# model for C3714506 achieved 0.01 validation rate at 0.33 validation recall (found 1/3 with pred=98)
# predicted 112.0/8107.0 genes associated with 14 training genes
# predicted association rate 0.014
# 3/3 new associations could have been predicted and were tested
# p hyper 0.036
#
# 1080/1131
# ignoring C0206724 as a predictor in network risk_gene
# model for C0206724 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1081/1131
# ignoring C4551851 as a predictor in network risk_gene
# model for C4551851 achieved 0.00 validation rate at 0.00 validation recall (found 0/3 with pred=0)
# predicted 2.0/8107.0 genes associated with 2 training genes
# predicted association rate 0.000
# 3/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1082/1131
# ignoring C1853198 as a predictor in network risk_gene
# model for C1853198 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1083/1131
# ignoring C3542022 as a predictor in network risk_gene
# model for C3542022 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1084/1131
# ignoring C1848561 as a predictor in network risk_gene
# model for C1848561 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1085/1131
# ignoring C0265227 as a predictor in network risk_gene
# model for C0265227 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1086/1131
# ignoring C3278404 as a predictor in network risk_gene
# model for C3278404 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1087/1131
# ignoring C0027719 as a predictor in network risk_gene
# model for C0027719 achieved 0.00 validation rate at 1.00 validation recall (found 9/9 with pred=8105)
# predicted 8107.0/8107.0 genes associated with 2 training genes
# predicted association rate 1.000
# 9/9 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1088/1131
# ignoring C0158761 as a predictor in network risk_gene
# model for C0158761 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1089/1131
# ignoring C1835828 as a predictor in network risk_gene
# model for C1835828 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1090/1131
# ignoring C2673914 as a predictor in network risk_gene
# model for C2673914 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1091/1131
# **** no predictable genes for C2609071
# 1092/1131
# ignoring C4551510 as a predictor in network risk_gene
# model for C4551510 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1093/1131
# ignoring C0264611 as a predictor in network risk_gene
# model for C0264611 achieved 0.00 validation rate at 0.00 validation recall (found 0/1 with pred=0)
# predicted 2.0/8107.0 genes associated with 2 training genes
# predicted association rate 0.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1094/1131
# **** no predictable genes for C1842983
# 1095/1131
# ignoring C0265222 as a predictor in network risk_gene
# model for C0265222 achieved 0.00 validation rate at 1.00 validation recall (found 4/4 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 4/11 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1096/1131
# ignoring C2936502 as a predictor in network risk_gene
# model for C2936502 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1097/1131
# **** no predictable genes for C1838854
# 1098/1131
# ignoring C0432198 as a predictor in network risk_gene
# model for C0432198 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1099/1131
# ignoring C0751084 as a predictor in network risk_gene
# model for C0751084 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1100/1131
# ignoring C1623209 as a predictor in network risk_gene
# model for C1623209 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1101/1131
# ignoring C0220744 as a predictor in network risk_gene
# model for C0220744 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1102/1131
# ignoring C1720956 as a predictor in network risk_gene
# model for C1720956 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1103/1131
# ignoring C4025846 as a predictor in network risk_gene
# model for C4025846 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8105)
# predicted 8107.0/8107.0 genes associated with 2 training genes
# predicted association rate 1.000
# 1/4 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1104/1131
# ignoring C2931208 as a predictor in network risk_gene
# model for C2931208 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1105/1131
# ignoring C1859353 as a predictor in network risk_gene
# model for C1859353 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1106/1131
# ignoring C1861355 as a predictor in network risk_gene
# model for C1861355 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1107/1131
# **** no predictable genes for C0004030
# 1108/1131
# ignoring C0345958 as a predictor in network risk_gene
# model for C0345958 achieved 0.00 validation rate at 1.00 validation recall (found 25/25 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 25/31 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1109/1131
# ignoring C4551631 as a predictor in network risk_gene
# model for C4551631 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1110/1131
# **** no predictable genes for C4551856
# 1111/1131
# ignoring C0752160 as a predictor in network risk_gene
# model for C0752160 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1112/1131
# ignoring C0752161 as a predictor in network risk_gene
# model for C0752161 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1113/1131
# ignoring C0752164 as a predictor in network risk_gene
# model for C0752164 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1114/1131
# ignoring C1956260 as a predictor in network risk_gene
# model for C1956260 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1115/1131
# ignoring C1864205 as a predictor in network risk_gene
# model for C1864205 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 3/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1116/1131
# ignoring C0496956 as a predictor in network risk_gene
# model for C0496956 achieved 0.00 validation rate at 1.00 validation recall (found 39/39 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 39/40 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1117/1131
# ignoring C1387925 as a predictor in network risk_gene
# model for C1387925 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1118/1131
# **** no predictable genes for C3550704
# 1119/1131
# **** no predictable genes for C4551514
# 1120/1131
# ignoring C2748568 as a predictor in network risk_gene
# model for C2748568 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1121/1131
# ignoring C4551772 as a predictor in network risk_gene
# model for C4551772 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1122/1131
# ignoring C1744559 as a predictor in network risk_gene
# model for C1744559 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1123/1131
# ignoring C3502075 as a predictor in network risk_gene
# model for C3502075 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8105)
# predicted 8107.0/8107.0 genes associated with 2 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1124/1131
# ignoring C0265331 as a predictor in network risk_gene
# model for C0265331 achieved 0.00 validation rate at 1.00 validation recall (found 3/3 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 3/3 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1125/1131
# ignoring C4012050 as a predictor in network risk_gene
# model for C4012050 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1126/1131
# **** no predictable genes for C1838867
# 1127/1131
# ignoring C1856016 as a predictor in network risk_gene
# model for C1856016 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1128/1131
# ignoring C1850792 as a predictor in network risk_gene
# model for C1850792 achieved 0.00 validation rate at 1.00 validation recall (found 2/2 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 2/2 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1129/1131
# ignoring C3151136 as a predictor in network risk_gene
# model for C3151136 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000
#
# 1130/1131
# ignoring C1834673 as a predictor in network risk_gene
# model for C1834673 achieved 0.00 validation rate at 1.00 validation recall (found 1/1 with pred=8106)
# predicted 8107.0/8107.0 genes associated with 1 training genes
# predicted association rate 1.000
# 1/1 new associations could have been predicted and were tested
# p hyper 1.000

# %%
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#      target  n_new_genes_predictable  n_new_genes_total        F1       F05  \
# 0  C0036341                        0                  1       NaN       NaN
# 1  C0002395                        1                  1  0.137008  0.090324
# 2  C0007102                        3                  5  0.160450  0.108716
# 3  C0009375                        4                  5  0.166002  0.113240
# 4  C0011265                        3                  4  0.132597  0.087209
#
#          F2       ACC         J      PREC       REC  ...      fp    fn  \
# 0       NaN       NaN       NaN       NaN       NaN  ...     NaN   NaN
# 1  0.283572  0.864808  0.852086  0.073604  0.988636  ...  1095.0   1.0
# 2  0.306122  0.852843  0.629782  0.089482  0.775510  ...  1160.0  33.0
# 3  0.310819  0.871099  0.616210  0.093441  0.742857  ...  1009.0  36.0
# 4  0.276498  0.864438  0.863019  0.071006  1.000000  ...  1099.0   0.0
#
#    weight_risk_gene  weight_go_annotation  weight_encoded_PPI  \
# 0               NaN                   NaN                 NaN
# 1               0.1                   0.0                 0.0
# 2               0.4                   0.0                 0.6
# 3               0.8                   0.0                 0.9
# 4               0.1                   0.0                 0.0
#
#   validation_precision  validation_recall  n_genes_total  n_validated  \
# 0                  NaN                NaN            NaN          NaN
# 1             0.000913           1.000000         8107.0          1.0
# 2             0.000862           0.333333         8107.0          1.0
# 3             0.001982           0.500000         8107.0          2.0
# 4             0.002730           1.000000         8107.0          3.0
#
#        prob
# 0       NaN
# 1  0.136551
# 2  0.376610
# 3  0.080713
# 4  0.002564
#
# [5 rows x 28 columns]

# %%
df.to_csv("temporal_validation_gs_nra.csv") #graph_sparse, not require all
